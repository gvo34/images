# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='sgd', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
#  - 12s - loss: 2.1563 - acc: 0.1960 - val_loss: 1.9760 - val_acc: 0.2848
#
# Epoch 00001: val_loss improved from inf to 1.97596, saving model to model.weights.best.hdf5
# Epoch 2/50
#  - 7s - loss: 1.9382 - acc: 0.2938 - val_loss: 1.8404 - val_acc: 0.3478
#
# Epoch 00002: val_loss improved from 1.97596 to 1.84038, saving model to model.weights.best.hdf5
# Epoch 3/50
#  - 7s - loss: 1.7685 - acc: 0.3579 - val_loss: 1.6418 - val_acc: 0.4072
#
# Epoch 00003: val_loss improved from 1.84038 to 1.64181, saving model to model.weights.best.hdf5
# Epoch 4/50
#  - 7s - loss: 1.6562 - acc: 0.3970 - val_loss: 1.5046 - val_acc: 0.4676
#
# Epoch 00004: val_loss improved from 1.64181 to 1.50458, saving model to model.weights.best.hdf5
# Epoch 5/50
#  - 7s - loss: 1.5741 - acc: 0.4260 - val_loss: 1.4672 - val_acc: 0.4760
#
# Epoch 00005: val_loss improved from 1.50458 to 1.46716, saving model to model.weights.best.hdf5
# Epoch 6/50
#  - 7s - loss: 1.5096 - acc: 0.4515 - val_loss: 1.4495 - val_acc: 0.4780
#
# Epoch 00006: val_loss improved from 1.46716 to 1.44955, saving model to model.weights.best.hdf5
# Epoch 7/50
#  - 7s - loss: 1.4563 - acc: 0.4720 - val_loss: 1.5525 - val_acc: 0.4536
#
# Epoch 00007: val_loss did not improve from 1.44955
# Epoch 8/50
#  - 7s - loss: 1.4141 - acc: 0.4899 - val_loss: 1.4724 - val_acc: 0.4734
#
# Epoch 00008: val_loss did not improve from 1.44955
# Epoch 9/50
#  - 7s - loss: 1.3839 - acc: 0.5006 - val_loss: 1.2642 - val_acc: 0.5410
#
# Epoch 00009: val_loss improved from 1.44955 to 1.26421, saving model to model.weights.best.hdf5
# Epoch 10/50
#  - 7s - loss: 1.3500 - acc: 0.5155 - val_loss: 1.2262 - val_acc: 0.5642
#
# Epoch 00010: val_loss improved from 1.26421 to 1.22621, saving model to model.weights.best.hdf5
# Epoch 11/50
#  - 7s - loss: 1.3207 - acc: 0.5260 - val_loss: 1.2708 - val_acc: 0.5486
#
# Epoch 00011: val_loss did not improve from 1.22621
# Epoch 12/50
#  - 7s - loss: 1.2946 - acc: 0.5357 - val_loss: 1.1775 - val_acc: 0.5808
#
# Epoch 00012: val_loss improved from 1.22621 to 1.17753, saving model to model.weights.best.hdf5
# Epoch 13/50
#  - 7s - loss: 1.2674 - acc: 0.5456 - val_loss: 1.1911 - val_acc: 0.5746
#
# Epoch 00013: val_loss did not improve from 1.17753
# Epoch 14/50
#  - 7s - loss: 1.2422 - acc: 0.5541 - val_loss: 1.1894 - val_acc: 0.5808
#
# Epoch 00014: val_loss did not improve from 1.17753
# Epoch 15/50
#  - 7s - loss: 1.2154 - acc: 0.5668 - val_loss: 1.2361 - val_acc: 0.5568
#
# Epoch 00015: val_loss did not improve from 1.17753
# Epoch 16/50
#  - 7s - loss: 1.1961 - acc: 0.5719 - val_loss: 1.0816 - val_acc: 0.6216
#
# Epoch 00016: val_loss improved from 1.17753 to 1.08163, saving model to model.weights.best.hdf5
# Epoch 17/50
#  - 7s - loss: 1.1748 - acc: 0.5810 - val_loss: 1.0953 - val_acc: 0.6266
#
# Epoch 00017: val_loss did not improve from 1.08163
# Epoch 18/50
#  - 7s - loss: 1.1571 - acc: 0.5886 - val_loss: 1.0487 - val_acc: 0.6346
#
# Epoch 00018: val_loss improved from 1.08163 to 1.04872, saving model to model.weights.best.hdf5
# Epoch 19/50
#  - 7s - loss: 1.1417 - acc: 0.5937 - val_loss: 1.0381 - val_acc: 0.6450
#
# Epoch 00019: val_loss improved from 1.04872 to 1.03806, saving model to model.weights.best.hdf5
# Epoch 20/50
#  - 7s - loss: 1.1212 - acc: 0.6011 - val_loss: 1.1521 - val_acc: 0.5904
#
# Epoch 00020: val_loss did not improve from 1.03806
# Epoch 21/50
#  - 7s - loss: 1.1017 - acc: 0.6071 - val_loss: 1.0948 - val_acc: 0.6068
#
# Epoch 00021: val_loss did not improve from 1.03806
# Epoch 22/50
#  - 7s - loss: 1.0828 - acc: 0.6148 - val_loss: 1.0083 - val_acc: 0.6430
#
# Epoch 00022: val_loss improved from 1.03806 to 1.00827, saving model to model.weights.best.hdf5
# Epoch 23/50
#  - 7s - loss: 1.0672 - acc: 0.6206 - val_loss: 0.9753 - val_acc: 0.6616
#
# Epoch 00023: val_loss improved from 1.00827 to 0.97534, saving model to model.weights.best.hdf5
# Epoch 24/50
#  - 7s - loss: 1.0517 - acc: 0.6232 - val_loss: 1.0017 - val_acc: 0.6422
#
# Epoch 00024: val_loss did not improve from 0.97534
# Epoch 25/50
#  - 7s - loss: 1.0392 - acc: 0.6310 - val_loss: 0.9584 - val_acc: 0.6604
#
# Epoch 00025: val_loss improved from 0.97534 to 0.95837, saving model to model.weights.best.hdf5
# Epoch 26/50
#  - 7s - loss: 1.0273 - acc: 0.6334 - val_loss: 0.9539 - val_acc: 0.6646
#
# Epoch 00026: val_loss improved from 0.95837 to 0.95386, saving model to model.weights.best.hdf5
# Epoch 27/50
#  - 7s - loss: 1.0146 - acc: 0.6399 - val_loss: 0.9758 - val_acc: 0.6490
#
# Epoch 00027: val_loss did not improve from 0.95386
# Epoch 28/50
#  - 7s - loss: 1.0019 - acc: 0.6451 - val_loss: 0.9223 - val_acc: 0.6834
#
# Epoch 00028: val_loss improved from 0.95386 to 0.92227, saving model to model.weights.best.hdf5
# Epoch 29/50
#  - 7s - loss: 0.9875 - acc: 0.6495 - val_loss: 0.9170 - val_acc: 0.6828
#
# Epoch 00029: val_loss improved from 0.92227 to 0.91697, saving model to model.weights.best.hdf5
# Epoch 30/50
#  - 7s - loss: 0.9719 - acc: 0.6544 - val_loss: 1.0221 - val_acc: 0.6406
#
# Epoch 00030: val_loss did not improve from 0.91697
# Epoch 31/50
#  - 7s - loss: 0.9639 - acc: 0.6611 - val_loss: 0.9257 - val_acc: 0.6748
#
# Epoch 00031: val_loss did not improve from 0.91697
# Epoch 32/50
#  - 7s - loss: 0.9477 - acc: 0.6670 - val_loss: 0.9486 - val_acc: 0.6624
#
# Epoch 00032: val_loss did not improve from 0.91697
# Epoch 33/50
#  - 7s - loss: 0.9362 - acc: 0.6682 - val_loss: 0.8787 - val_acc: 0.6982
#
# Epoch 00033: val_loss improved from 0.91697 to 0.87867, saving model to model.weights.best.hdf5
# Epoch 34/50
#  - 7s - loss: 0.9290 - acc: 0.6709 - val_loss: 0.9492 - val_acc: 0.6630
#
# Epoch 00034: val_loss did not improve from 0.87867
# Epoch 35/50
#  - 7s - loss: 0.9196 - acc: 0.6737 - val_loss: 0.8803 - val_acc: 0.6994
#
# Epoch 00035: val_loss did not improve from 0.87867
# Epoch 36/50
#  - 7s - loss: 0.9096 - acc: 0.6778 - val_loss: 1.0359 - val_acc: 0.6246
#
# Epoch 00036: val_loss did not improve from 0.87867
# Epoch 37/50
#  - 7s - loss: 0.8996 - acc: 0.6822 - val_loss: 0.8617 - val_acc: 0.7058
#
# Epoch 00037: val_loss improved from 0.87867 to 0.86172, saving model to model.weights.best.hdf5
# Epoch 38/50
#  - 7s - loss: 0.8839 - acc: 0.6867 - val_loss: 0.8439 - val_acc: 0.7062
#
# Epoch 00038: val_loss improved from 0.86172 to 0.84390, saving model to model.weights.best.hdf5
# Epoch 39/50
#  - 7s - loss: 0.8799 - acc: 0.6876 - val_loss: 0.8644 - val_acc: 0.6964
#
# Epoch 00039: val_loss did not improve from 0.84390
# Epoch 40/50
#  - 7s - loss: 0.8645 - acc: 0.6939 - val_loss: 0.8378 - val_acc: 0.7110
#
# Epoch 00040: val_loss improved from 0.84390 to 0.83779, saving model to model.weights.best.hdf5
# Epoch 41/50
#  - 7s - loss: 0.8568 - acc: 0.6938 - val_loss: 0.8279 - val_acc: 0.7116
#
# Epoch 00041: val_loss improved from 0.83779 to 0.82788, saving model to model.weights.best.hdf5
# Epoch 42/50
#  - 8s - loss: 0.8470 - acc: 0.6980 - val_loss: 0.8160 - val_acc: 0.7202
#
# Epoch 00042: val_loss improved from 0.82788 to 0.81596, saving model to model.weights.best.hdf5
# Epoch 43/50
#  - 7s - loss: 0.8432 - acc: 0.7016 - val_loss: 0.8255 - val_acc: 0.7106
#
# Epoch 00043: val_loss did not improve from 0.81596
# Epoch 44/50
#  - 7s - loss: 0.8315 - acc: 0.7069 - val_loss: 0.8962 - val_acc: 0.6938
#
# Epoch 00044: val_loss did not improve from 0.81596
# Epoch 45/50
#  - 7s - loss: 0.8222 - acc: 0.7068 - val_loss: 0.8257 - val_acc: 0.7114
#
# Epoch 00045: val_loss did not improve from 0.81596
# Epoch 46/50
#  - 7s - loss: 0.8126 - acc: 0.7131 - val_loss: 0.8168 - val_acc: 0.7136
#
# Epoch 00046: val_loss did not improve from 0.81596
# Epoch 47/50
#  - 7s - loss: 0.8035 - acc: 0.7158 - val_loss: 0.8144 - val_acc: 0.7100
#
# Epoch 00047: val_loss improved from 0.81596 to 0.81444, saving model to model.weights.best.hdf5
# Epoch 48/50
#  - 7s - loss: 0.7962 - acc: 0.7171 - val_loss: 0.8148 - val_acc: 0.7114
#
# Epoch 00048: val_loss did not improve from 0.81444
# Epoch 49/50
#  - 7s - loss: 0.7871 - acc: 0.7224 - val_loss: 0.7913 - val_acc: 0.7234
#
# Epoch 00049: val_loss improved from 0.81444 to 0.79128, saving model to model.weights.best.hdf5
# Epoch 50/50
#  - 7s - loss: 0.7798 - acc: 0.7253 - val_loss: 0.7954 - val_acc: 0.7280
#
# Epoch 00050: val_loss did not improve from 0.79128

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7161

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
